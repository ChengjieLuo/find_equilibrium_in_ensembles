# %%
import numpy as np
import matplotlib.pyplot as plt
from ufun import *

# %%
filename='/Users/chengjie/Documents/Goettingen/projects/charged_phase_separation/find_equilibrium_in_ensembles/submit/data_test/zs_0.800000000000000_-0.200000000000000_-1.000000000000000_1.000000000000000_0.000000000000000__chi-7.0_numbeta2_alldata.txt'
num_comp=5
num_beta=2
num_coord=128
Lbetas,omegas,phis,psi,Js,total_energy,errors=analyze_from_filename(filename,num_comp,num_beta,num_coord)
